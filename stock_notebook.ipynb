# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
import yfinance as yf
import datetime as dt

# %%
stock="NIFTYBEES.NS"
start=dt.datetime(2002,1,1)
end=dt.datetime(2025,1,31)

df=yf.download (stock,start,end)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
df.head()

# Display the first few rows
# Out:
# Price             Close         High          Low         Open       Volume
# Ticker     NIFTYBEES.NS NIFTYBEES.NS NIFTYBEES.NS NIFTYBEES.NS NIFTYBEES.NS
# Date
# 2009-01-02    30.556000    30.945000    30.299999    30.600000      1344830
# 2009-01-05    31.174999    31.370001    30.700001    30.700001      2429180
# 2009-01-06    31.124001    31.480000    30.603001    31.100000      1418730
# 2009-01-07    29.264999    31.500000    28.900000    31.379999      5724640
# 2009-01-09    28.855000    29.500000    28.030001    29.000000      1820800

# %%
df.tail()
# display the last rows
# Out:
# Price             Close         High          Low         Open       Volume
# Ticker     NIFTYBEES.NS NIFTYBEES.NS NIFTYBEES.NS NIFTYBEES.NS NIFTYBEES.NS
# Date
# 2025-01-24   258.190002   260.950012   257.700012   260.299988      5458441
# 2025-01-27   255.690002   257.679993   255.139999   257.489990     10984113
# 2025-01-28   257.329987   259.140015   255.949997   257.000000      6575668
# 2025-01-29   259.380005   259.500000   257.200012   258.500000      4481256
# 2025-01-30   260.220001   260.980011   259.000000   259.049988      6330889

# %%
df.shape
# Out:
# (3963, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3963 entries, 2009-01-02 to 2025-01-30
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   (Close, NIFTYBEES.NS)   3963 non-null   float64
#  1   (High, NIFTYBEES.NS)    3963 non-null   float64
#  2   (Low, NIFTYBEES.NS)     3963 non-null   float64
#  3   (Open, NIFTYBEES.NS)    3963 non-null   float64
#  4   (Volume, NIFTYBEES.NS)  3963 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 185.8 KB

# %%
df.isnull().sum()
# check for missing values
# Out:
# Price   Ticker
# Close   NIFTYBEES.NS    0
# High    NIFTYBEES.NS    0
# Low     NIFTYBEES.NS    0
# Open    NIFTYBEES.NS    0
# Volume  NIFTYBEES.NS    0
# dtype: int64

# %%
df.describe()
# Summary statistics
# Out:
# Price         Close         High          Low         Open        Volume
# Ticker NIFTYBEES.NS NIFTYBEES.NS NIFTYBEES.NS NIFTYBEES.NS  NIFTYBEES.NS
# count   3963.000000  3963.000000  3963.000000  3963.000000  3.963000e+03
# mean     112.265236   113.740816   111.179226   113.014422  1.380150e+06
# std       63.642218    64.699912    63.033473    64.494876  1.849296e+06
# min       13.020000    13.033000    12.905000     0.000000  0.000000e+00
# 25%       59.393986    59.681499    58.957499    59.343090  2.689600e+05
# 50%       89.459999    90.000000    88.907997    89.695000  6.594400e+05
# 75%      154.099998   158.949997   151.714996   156.754997  1.924451e+06
# max      291.970001   293.989990   291.350006   291.950012  3.249676e+07

# %%
df=df.reset_index()

# %%
df.columns
# Out:
# MultiIndex([(  'Date',             ''),
#             ( 'Close', 'NIFTYBEES.NS'),
#             (  'High', 'NIFTYBEES.NS'),
#             (   'Low', 'NIFTYBEES.NS'),
#             (  'Open', 'NIFTYBEES.NS'),
#             ('Volume', 'NIFTYBEES.NS')],
#            names=['Price', 'Ticker'])

# %%
# Save to CSV
df.to_csv("niftybees_data.csv")

# %%
# Load the dataset
data = pd.read_csv("niftybees_data.csv")

# %%
data.head()
# Out:
#     Price        Date               Close                High  \
# 0  Ticker         NaN        NIFTYBEES.NS        NIFTYBEES.NS
# 1       0  2009-01-02  30.555999755859375   30.94499969482422
# 2       1  2009-01-05  31.174999237060547    31.3700008392334
# 3       2  2009-01-06  31.124000549316406  31.479999542236328
# 4       3  2009-01-07  29.264999389648438                31.5
#
#                   Low                Open        Volume
# 0        NIFTYBEES.NS        NIFTYBEES.NS  NIFTYBEES.NS
# 1  30.299999237060547  30.600000381469727       1344830
# 2  30.700000762939453  30.700000762939453       2429180
# 3   30.60300064086914  31.100000381469727       1418730
# 4  28.899999618530273    31.3799991607666       5724640

# %%
import plotly.graph_objects as go
fig = go.Figure(data=[go.Candlestick(
    x=data['Date'],
    open=data['Open'],
    high=data['High'],
    low=data['Low'],
    close=data['Close']
)])
fig.update_layout(xaxis_rangeslider_visible=False)
fig.show()

# %%
df=df.drop(['Date'],axis=1)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_14008\1039762504.py:1: PerformanceWarning:
#
# dropping on a non-lexsorted multi-index without a level parameter may impact performance.

# %%
df.head()
# Out:
# Price         Close         High          Low         Open       Volume
# Ticker NIFTYBEES.NS NIFTYBEES.NS NIFTYBEES.NS NIFTYBEES.NS NIFTYBEES.NS
# 0         30.556000    30.945000    30.299999    30.600000      1344830
# 1         31.174999    31.370001    30.700001    30.700001      2429180
# 2         31.124001    31.480000    30.603001    31.100000      1418730
# 3         29.264999    31.500000    28.900000    31.379999      5724640
# 4         28.855000    29.500000    28.030001    29.000000      1820800

# %%
plt.figure(figsize=(12,6))
plt.plot(df['Close'],label=f'{stock} Close Price',color='blue',linewidth=1)
plt.title(f'{stock} Close price over time')
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.legend()
plt.grid()
plt.show()

# %%
plt.figure(figsize=(12,6))
plt.plot(df['Open'],label=f'{stock} Open Price',color='green',linewidth=1)
plt.title(f'{stock} Open price over time')
plt.xlabel('Date')
plt.ylabel('Open Price')
plt.grid()
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12,6))
plt.plot(df['High'],label=f'{stock} High Price',color='red',linewidth=1)
plt.title(f'{stock} High price over time')
plt.legend()
plt.xlabel('Date')
plt.ylabel('High Price')
plt.grid()
plt.show()

# %%
plt.figure(figsize=(12,6))
plt.plot(df['Volume'],label=f'{stock} Volume Price',color='purple',linewidth=1)
plt.title(f'{stock} Volume price over time')
plt.xlabel('Date')
plt.ylabel('Volume Price')
plt.grid()
plt.legend()
plt.show()

# %%
# Calculate moving averages
SMA100 = df.Close.rolling(window=100).mean()
SMA200 = df.Close.rolling(window=200).mean()

# Plot with moving averages
plt.figure(figsize=(12, 6))
plt.plot(df.Close, label=f'{stock} Close Price', color='blue')
plt.plot(SMA100, label=f'{stock} 100-Day SMA', color='orange')
plt.plot(SMA200, label=f'{stock} 200-Day SMA', color='green')
plt.legend()
plt.grid()
plt.show()

# %%
EMA100 = df.Close.ewm(span=100, adjust = False).mean()
EMA200 = df.Close.ewm(span=200, adjust = False).mean()
# Plot with exponential moving averages
plt.figure(figsize=(12, 6))
plt.plot(df.Close, label=f'{stock} Close Price', color='blue')
plt.plot(EMA100, label=f'{stock} 100-Day EMA',color='red')
plt.plot(EMA200, label=f'{stock} 200-Day EMA', color='green')
plt.legend()
plt.grid()
plt.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from keras.layers import Activation,Dropout
from keras.layers import Dense
from keras.layers import LSTM
from keras.models import Sequential

# %%
xtrain=pd.DataFrame(df['Close'][0:int(len(df)*0.80)])
xtest=pd.DataFrame(df['Close'][int(len(df)*0.80):int(len(df))])

# %%
xtrain.shape
# Out:
# (3170, 1)

# %%
xtest.shape
# Out:
# (793, 1)

# %%
scalar=MinMaxScaler(feature_range=(0,1))
scaled_data=scalar.fit_transform(xtrain)

# %%
scaled_data
# Out:
# array([[0.09433535],
#        [0.09766528],
#        [0.09739093],
#        ...,
#        [0.98144065],
#        [0.98176341],
#        [0.97611489]])

# %%
scaled_data.shape[0]
# Out:
# 3170

# %%
X_train=[]
y_train=[]
for i in range(100,scaled_data.shape[0]):
    X_train.append(scaled_data[i-100:i])
    y_train.append(scaled_data[i,0])
X_train,y_train=np.array(X_train),np.array(y_train)

# %%
X_train.shape
# Out:
# (3070, 100, 1)

# %%
model = Sequential()

# First LSTM layer with the correct input_shape
model.add(LSTM(units=50, activation='relu', return_sequences=True, input_shape= (X_train.shape[1],1)))
model.add(Dropout(0.2))

# Second LSTM layer
model.add(LSTM(units=60, activation='relu', return_sequences=True))
model.add(Dropout(0.3))

# Third LSTM layer
model.add(LSTM(units=80, activation='relu', return_sequences=True))
model.add(Dropout(0.4))

# Fourth LSTM layer
model.add(LSTM(units=120, activation='relu'))
model.add(Dropout(0.5))

# Output layer
model.add(Dense(units=1))
# Out:
# c:\stock-price-prediction\venv\Lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning:
#
# Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 100, 50)        │        10,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 100, 50)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 100, 60)        │        26,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 100, 60)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_2 (LSTM)                   │ (None, 100, 80)        │        45,120 │
# ...

# %%
model.compile(optimizer='adam',loss='mean_squared_error')
model.fit(X_train,y_train,epochs=20,batch_size=32)
# Out:
# Epoch 1/20
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 18s 123ms/step - loss: 0.0535
# Epoch 2/20
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 11s 110ms/step - loss: 0.0065
# Epoch 3/20
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 14s 145ms/step - loss: 0.0050
# Epoch 4/20
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 14s 147ms/step - loss: 0.0052
# Epoch 5/20
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 8s 88ms/step - loss: 0.0038
# Epoch 6/20
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 8s 81ms/step - loss: 0.0048
# Epoch 7/20
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 8s 79ms/step - loss: 0.0034
# Epoch 8/20
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 7s 77ms/step - loss: 0.0032
# Epoch 9/20
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 8s 79ms/step - loss: 0.0035
# Epoch 10/20
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 8s 79ms/step - loss: 0.0030
# Epoch 11/20
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 7s 78ms/step - loss: 0.0030
# Epoch 12/20
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 10s 103ms/step - loss: 0.0029
# Epoch 13/20
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 8s 88ms/step - loss: 0.0026
# Epoch 14/20
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 8s 83ms/step - loss: 0.0027
# ...

# %%
past_100=xtrain.tail(100)

# %%
final_data = pd.concat([past_100, xtrain], ignore_index=True)

# %%
final_data.head()
# Out:
# Ticker  NIFTYBEES.NS
# 0         168.679993
# 1         169.679993
# 2         170.399994
# 3         169.850006
# 4         169.330002

# %%
inputscaled_data=scalar.fit_transform(final_data)

# %%
X_test=[]
y_test=[]
for i in range(100,inputscaled_data.shape[0]):
    X_test.append(inputscaled_data[i-100:i])
    y_test.append(inputscaled_data[i,0])
X_test,y_test=np.array(X_test),np.array(y_test)

# %%
X_test.shape
# Out:
# (3170, 100, 1)

# %%
y_pred=model.predict(X_test)
# Out:
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step

# %%
y_pred.shape
# Out:
# (3170, 1)

# %%
scalar.scale_
# Out:
# array([0.00537953])

# %%
scalar_factor=1/0.00537953
y_pred=y_pred*scalar_factor
y_test=y_test*scalar_factor

# %%
plt.figure(figsize=(12, 6))
plt.plot(y_test, label='Orginal Price', color='green',linewidth=1)
plt.plot(y_pred, label='Predicted Price', color='red',linewidth=1)
plt.legend()
plt.grid()
plt.show()

# %%
model.save('stock_model.keras')

# %%
# import pickle

# # Save the scaler
# with open('scalar.pkl', 'wb') as file:
#     pickle.dump(scalar, file)
